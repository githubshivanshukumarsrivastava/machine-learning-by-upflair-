# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\SHIVANSHU SRIVASTAVA\OneDrive\Desktop\ml by upflair\project\loyal\cust_satisfaction.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['Customer Type'],axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
#
# NameError: name 'y' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
obj_classifier=RandomForestClassifier()

# %%
obj_regressor=RandomForestRegressor()

# %%
obj_classifier.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
obj_classifier.fit(x_train,y_train)

# %%
# N ESTIMATOR
